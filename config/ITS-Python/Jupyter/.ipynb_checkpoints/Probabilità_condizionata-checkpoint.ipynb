# %%
def probabilita_condizionale(p_a_inter_b, p_b):
    """
    Calcola la probabilità condizionata P(A|B) = P(A ∩ B) / P(B)

    Parametri:
        p_a_inter_b (float): probabilità dell'intersezione A ∩ B
        p_b (float): probabilità di B

    Ritorna:
        float: probabilità condizionata P(A|B)
    """
    if p_b == 0:
        raise ValueError("P(B) non può essere zero")
    return p_a_inter_b / p_b

# %%
#Esercizio due dadi somma 6
# === Input utente ===
print("Calcolo della probabilità condizionata P(A|B)")
p_a_inter_b = (2 / 36)
p_b = (5 / 36)

# === Calcolo ===
p_a_dato_b = probabilita_condizionale(p_a_inter_b, p_b)

# === Output ===
print("\nRisultato:")
print(f"P(A|B) = {p_a_dato_b:.4f} → {p_a_dato_b:.2%}")
print(f"Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è {p_a_dato_b:.2%}")
# Out:
# Calcolo della probabilità condizionata P(A|B)
#
# Risultato:
# P(A|B) = 0.4000 → 40.00%
# Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è 40.00%

# %%
#Esercizio palline Rosse e Blu, grandi e picccole 
print ("Calcolo della probabilità condizionata P(A|B)")
p_a_inter_b = (3 / 10)
p_b = (7 / 10)

p_a_dato_b  = probabilita_condizionale(p_a_inter_b, p_b)

print("\n Risultato")
print(f"P(A|B) = {p_a_dato_b:.4f} → {p_a_dato_b:.2%}")
print(f"Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è {p_a_dato_b:.2%}")
# Out:
# Calcolo della probabilità condizionata P(A|B)
#
#  Risultato
# P(A|B) = 0.4286 → 42.86%
# Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è 42.86%

# %%
print ("Calcolo della probabilità condizionata P(A|B)")
p_a_inter_b = (5 / 100)
p_b = (25 / 100)

p_a_dato_b  = probabilita_condizionale(p_a_inter_b, p_b)

print("\n Risultato")
print(f"P(A|B) = {p_a_dato_b:.4f} → {p_a_dato_b:.2%}")
print(f"Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è {p_a_dato_b:.2%}")
# Out:
# Calcolo della probabilità condizionata P(A|B)
#
#  Risultato
# P(A|B) = 0.2000 → 20.00%
# Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è 20.00%

# %%
#Esercizio parco auto
print ("Calcolo della probabilità condizionata P(A|B)")
p_a_inter_b = (54 / 300)
p_b = (130 / 300)

p_a_dato_b  = probabilita_condizionale(p_a_inter_b, p_b)

print("\n Risultato")
print(f"P(A|B) = {p_a_dato_b:.4f} → {p_a_dato_b:.2%}")
print(f"Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è {p_a_dato_b:.2%}")
# Out:
# Calcolo della probabilità condizionata P(A|B)
#
#  Risultato
# P(A|B) = 0.4154 → 41.54%
# Interpretazione: sapendo che B è avvenuto, la probabilità che si verifichi anche A è 41.54%
